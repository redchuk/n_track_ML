# %%
import pandas as pd
from pathlib import Path

output_dirs = ['/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f1', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f2', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f3', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f1', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f2', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f3', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f1', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f2', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f3', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k30_f1', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k30_f2', \
               '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k30_f3', \
              ]

files = []
for d in output_dirs:
    files.extend(Path(d).glob('*/*.csv'))

scores_all = []

for f in files:
    df = pd.read_csv(f)
    df['dir'] = str(Path(f).parent)
    scores_all.append(df)

scores_all = pd.concat(scores_all)

# %%
df = scores_all.copy()
print(df['dir'].unique())
print(df['fset'].unique())
print(df['cv'].unique())
print(df['kernel_size'].unique())
print('repeats: ' + str(df['repeat'].max()))
df.head()
# Out:
# ['/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f1/202205051815'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f2/202205051816'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k15_f3/202205051817'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f1/202205051247'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f2/202205051248'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k20_f3/202205051249'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f1/202205051249'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f1/202205051818'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f2/202205051250'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f2/202205051819'
#  '/proj/hajaalin/Projects/n_track_ML/output/cross-validation/k25_f3/202205051251'
# ...

# %%
df.groupby(['kernel_size','fset',])['accuracy'].agg(['mean','std','count'])
# Out:
#                                  mean       std  count
# kernel_size fset
# 15          f_mot            0.607835  0.109606     80
#             f_mot_morph      0.573481  0.101090     80
#             f_mot_morph_dyn  0.737488  0.194751     80
# 20          f_mot            0.622589  0.121023    240
#             f_mot_morph      0.546524  0.089387    240
#             f_mot_morph_dyn  0.755764  0.180982    240
# 25          f_mot            0.631034  0.121551     80
#             f_mot_morph      0.559938  0.099020     80
#             f_mot_morph_dyn  0.760834  0.185816     80
# 30          f_mot            0.627878  0.117972     80
#             f_mot_morph      0.536992  0.088026     80
#             f_mot_morph_dyn  0.761398  0.183305     80

# %%
skt = pd.read_csv('/proj/hajaalin/Projects/n_track_ML/output/cross-validation/cv_sktime_20220401.csv')
skt.head()
# Out:
#    accuracy  precision    recall        f1                    cv  \
# 0  0.520000   0.617647  0.477273  0.538462  StratifiedGroupKFold
# 1  0.565217   0.666667  0.536585  0.594595  StratifiedGroupKFold
# 2  0.500000   0.500000  0.361111  0.419355  StratifiedGroupKFold
# 3  0.547945   0.488889  0.687500  0.571429  StratifiedGroupKFold
# 4  0.558824   0.486486  0.620690  0.545455  StratifiedGroupKFold
#
#       classifier   fset
# 0  KNeighborsTSC  f_mot
# 1  KNeighborsTSC  f_mot
# 2  KNeighborsTSC  f_mot
# 3  KNeighborsTSC  f_mot
# 4  KNeighborsTSC  f_mot

# %%
skt.groupby(['classifier','fset'])['accuracy'].agg(['mean','std','count'])
# Out:
#                                    mean       std  count
# classifier    fset
# KNeighborsTSC f_mot            0.498581  0.049386     80
#               f_mot_morph      0.556025  0.060314     80
#               f_mot_morph_dyn  0.496825  0.050823     80
# Rocket        f_mot            0.505623  0.052148     80
#               f_mot_morph      0.486711  0.061856     80
#               f_mot_morph_dyn  0.453967  0.053172     80
